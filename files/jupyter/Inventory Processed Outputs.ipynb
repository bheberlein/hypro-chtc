# %%
from pathlib import Path

import pandas as pd

# %%
from enspec.processing.utilities.check_outputs import inventory

# %%
farnsworth = Path('Z:')

# Processed data directory
data_directory = farnsworth/'data/processed/airborne/Test/HARS_2024/refl'
# Job list file
joblist_file = farnsworth/'users/bheberlein/processing/2024/HARS/raw-inputs/HARS_2024_JobList.txt'

# %%
df = inventory(data_directory, joblist_file=joblist_file, overwrite=True)
# Out:
# SESSION: HARS_20240610
#  - HARS_20240610_01 (1)
#  - HARS_20240610_02 (2)
#  - HARS_20240610_03 (3)
#  - HARS_20240610_04 (4)
#  - HARS_20240610_05 (5)
#  - HARS_20240610_06 (6)
#  - HARS_20240610_07 (7)
#  - HARS_20240610_08 (8)
#  - HARS_20240610_09 (9)
#  - HARS_20240610_10 (10)
# SESSION: HARS_20240624
#  - HARS_20240624_01 (1)
#  - HARS_20240624_02 (2)
#  - HARS_20240624_03 (3)
#  - HARS_20240624_04 (4)
#  - HARS_20240624_05 (5)
#  - HARS_20240624_06 (6)
#  - HARS_20240624_07 (7)
#  - HARS_20240624_08 (8)
#  - HARS_20240624_09 (9)
#  - HARS_20240624_10 (10)
#  - HARS_20240624_11 (11)
#  - HARS_20240624_12 (12)
#  - HARS_20240624_13 (13)
#  - HARS_20240624_14 (14)
#  - HARS_20240624_15 (15)
# SESSION: HARS_20240703
#  - HARS_20240703_01 (1)
#  - HARS_20240703_02 (2)
#  - HARS_20240703_03 (3)
#  - HARS_20240703_04 (4)
#  - HARS_20240703_05 (5)
#  - HARS_20240703_06 (6)
#  - HARS_20240703_07 (7)
#  - HARS_20240703_08 (8)
#  - HARS_20240703_09 (9)
#  - HARS_20240703_10 (10)
# ...

# %%
df
# Out:
#      site      date  image   disk memory completed
# 0    HARS  20240610      1   62GB   19GB      True
# 1    HARS  20240610      2   55GB   17GB      True
# 2    HARS  20240610      3   64GB   19GB      True
# 3    HARS  20240610      4   63GB   19GB      True
# 4    HARS  20240610      5   62GB   19GB      True
# ..    ...       ...    ...    ...    ...       ...
# 119  HARS  20240903     11   62GB   19GB       NaN
# 120  HARS  20240903     12   53GB   17GB      True
# 121  HARS  20240903     13   46GB   16GB      True
# 122  HARS  20240903     14   62GB   19GB      True
# 123  HARS  20240903     15   58GB   18GB       NaN
#
# [124 rows x 6 columns]
