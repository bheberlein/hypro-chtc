# %%
from enspec.io.envi import ENVI
from enspec.display.image import linear_percent_stretch
# Out:
# E:\sandbox\conda\envs\cole\Lib\site-packages\osgeo\osr.py:410: FutureWarning: Neither osr.UseExceptions() nor osr.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
image_file = r"Z:\data\processed\airborne\Test\SYEN_20180629_01\SYEN_20180629_01_Refl"

# %%
image = ENVI.from_file(image_file)

# %%
image
# Out:
# <ENVI int16 bsq, [474,1515×766]>

# %%
display_bands = [68, 47, 16]

# %%
image_data = image.data[display_bands].astype(np.float32)

# %%
mask = image_data[0] == -9999

# %%
mask.shape
# Out:
# (1515, 766)

# %%
plt.imshow(mask)

# %%
image_data[:, mask] = np.nan

# %%
image_rgb = linear_percent_stretch(image_data, axis=(1, 2))

# %%
# %matplotlib notebook

# %%
plt.imshow(image_rgb.transpose(1, 2, 0))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(image.data[:, 480, 200])
# Out:
# <img src="data:image/png;base64,..." width="640">
